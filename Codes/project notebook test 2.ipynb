# %% [markdown]
# # DATA MINING PROJECT 2
# SOME HINTS SUGGEST US TO FOCUS ON ATTRIBUTES CO2 AND LIGHT

# %%
import pandas as pd
data = pd.read_csv('datatraining.txt', sep=",")

# %%
data.head()
# Out:
#                   date  Temperature  Humidity  Light     CO2  HumidityRatio  \
# 1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25       0.004793
# 2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00       0.004783
# 3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50       0.004779
# 4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25       0.004772
# 5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50       0.004757
#
#    Occupancy
# 1          1
# 2          1
# 3          1
# 4          1
# 5          1

# %%
data.isnull().sum()
# Out:
# date             0
# Temperature      0
# Humidity         0
# Light            0
# CO2              0
# HumidityRatio    0
# Occupancy        0
# dtype: int64

# %%
data.describe()
# Out:
#        Temperature     Humidity        Light          CO2  HumidityRatio  \
# count  8143.000000  8143.000000  8143.000000  8143.000000    8143.000000
# mean     20.619084    25.731507   119.519375   606.546243       0.003863
# std       1.016916     5.531211   194.755805   314.320877       0.000852
# min      19.000000    16.745000     0.000000   412.750000       0.002674
# 25%      19.700000    20.200000     0.000000   439.000000       0.003078
# 50%      20.390000    26.222500     0.000000   453.500000       0.003801
# 75%      21.390000    30.533333   256.375000   638.833333       0.004352
# max      23.180000    39.117500  1546.333333  2028.500000       0.006476
#
#          Occupancy
# count  8143.000000
# mean      0.212330
# std       0.408982
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
data.dtypes
# Out:
# date              object
# Temperature      float64
# Humidity         float64
# Light            float64
# CO2              float64
# HumidityRatio    float64
# Occupancy          int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8143 entries, 1 to 8143
# Data columns (total 7 columns):
# date             8143 non-null object
# Temperature      8143 non-null float64
# Humidity         8143 non-null float64
# Light            8143 non-null float64
# CO2              8143 non-null float64
# HumidityRatio    8143 non-null float64
# Occupancy        8143 non-null int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 508.9+ KB

# %%
LightPlot = data['Light'].plot.kde()

# %%
plotTemp = data['Temperature'].plot.kde()

# %%
plotHumidity = data['Humidity'].plot.kde()

# %%
plotCO2 = data['CO2'].plot.kde()

# %%
plotOccupancy     = data['Occupancy'].plot.kde()

# %%
plotHumidityRatio = data['HumidityRatio'].plot.kde()

# %%
data.boxplot(column=['Light'])

# %%
data.boxplot(column=['HumidityRatio'])

# %%
data.boxplot(column=['CO2'])

# %%
data.plot(x='date', y='CO2')

# %%
data.plot(x='date', y='Light')

# %%
data.count()
# Out:
# date             8143
# Temperature      8143
# Humidity         8143
# Light            8143
# CO2              8143
# HumidityRatio    8143
# Occupancy        8143
# dtype: int64

# %%
data.plot(x='date', y='HumidityRatio')

# %%
data.plot(x='date', y='Humidity')

# %%
data.plot(x='date' , y='Temperature')

# %%
plotchart1 = data.Light.plot.hist()

# %%
plotchart1 = data.CO2.plot.hist()

# %%
data['Light'].corr(data['CO2']) 
#postitive correlation between this two attributes
# Out:
# 0.6640220567437009

# %%
data['Light'].corr(data['HumidityRatio'])
# Out:
# 0.23042021740650406

# %%
data['Humidity'].corr(data['HumidityRatio']) 
#almost the same
# Out:
# 0.9551980832358545

# %% [markdown]
# L'umidità relativa (o UR) è il rapporto tra la quantità di vapore acqueo contenuto in una massa d'aria e la quantità massima di vapore acqueo che la stessa massa d' aria riesce a contenere nelle stesse condizioni di temperatura e pressione.

# %%
data.corr()
# Out:
#                Temperature  Humidity     Light       CO2  HumidityRatio  \
# Temperature       1.000000 -0.141759  0.649942  0.559894       0.151762
# Humidity         -0.141759  1.000000  0.037828  0.439023       0.955198
# Light             0.649942  0.037828  1.000000  0.664022       0.230420
# CO2               0.559894  0.439023  0.664022  1.000000       0.626556
# HumidityRatio     0.151762  0.955198  0.230420  0.626556       1.000000
# Occupancy         0.538220  0.132964  0.907352  0.712235       0.300282
#
#                Occupancy
# Temperature     0.538220
# Humidity        0.132964
# Light           0.907352
# CO2             0.712235
# HumidityRatio   0.300282
# Occupancy       1.000000

# %% [markdown]
# Sono tutte correlazioni positive, tranne humidity e temperature che però è vicina allo 0. Non so se considerare occupancy ma non credo perche binario. forse sarebbe piu utile prima normalizzare il dataset.
# Una super correlazione c'è tra light e occupancy che potrebbe voler dire che la stanza è occupata quanod la luce accessa. Ovvio ma comunque utile da considerare. .
# medesima cosa accade con co2 e occupancy anche se piu bassa. ad ogni modo i piu interessanti da studiare sembrano proprio co2  light.

# %%
#provo a rimuovere il humidity ratio
df = data [['Temperature','Humidity','Light','CO2']]

# %%
df.head()#ho deciso di rimuovere anche occupancy, non credo abbia senso utilizzarlo al di fuori del data understanding
# Out:
#    Temperature  Humidity  Light     CO2
# 1        23.18   27.2720  426.0  721.25
# 2        23.15   27.2675  429.5  714.00
# 3        23.15   27.2450  426.0  713.50
# 4        23.15   27.2000  426.0  708.25
# 5        23.10   27.2000  426.0  704.50

# %% [raw]
# #un altro gruppo ha deciso di utlizzare il training per analisi e validation e poi unire i due test set per farne un unico solo.

# %%
df.dtypes
# Out:
# Temperature    float64
# Humidity       float64
# Light          float64
# CO2            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Temperature    0
# Humidity       0
# Light          0
# CO2            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8143 entries, 1 to 8143
# Data columns (total 4 columns):
# Temperature    8143 non-null float64
# Humidity       8143 non-null float64
# Light          8143 non-null float64
# CO2            8143 non-null float64
# dtypes: float64(4)
# memory usage: 318.1 KB

# %%
import seaborn as sns
import matplotlib.pylab as plt
corr = df.corr()
plt.subplots(figsize =(4, 4))
hm = sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values, annot=True)

# %%
df.corr(method='pearson', min_periods=1)
# Out:
#              Temperature  Humidity     Light       CO2
# Temperature     1.000000 -0.141759  0.649942  0.559894
# Humidity       -0.141759  1.000000  0.037828  0.439023
# Light           0.649942  0.037828  1.000000  0.664022
# CO2             0.559894  0.439023  0.664022  1.000000

# %%
df.isnull().any()
# Out:
# Temperature    False
# Humidity       False
# Light          False
# CO2            False
# dtype: bool

# %%
df['Light'].corr(df['CO2'])
# Out:
# 0.6640220567437009

# %%
df[df['Light'] == 0]['CO2'].sum()
# Out:
# 2527832.566666667

# %%
plt.scatter(data[data['Occupancy'] == 0]['CO2'], 
            data[data['Occupancy'] == 0]['Temperature'], color='g', marker='*', label='Not Occupied')
plt.scatter(data[data['Occupancy'] == 1]['CO2'], 
            data[data['Occupancy'] == 1]['Temperature'], color='r',label='Occupied')
plt.xlabel('CO2')
plt.ylabel('Temperature')
plt.legend()
plt.show()

# %%
plt.scatter(data[data['Occupancy'] == 0]['CO2'], 
            data[data['Occupancy'] == 0]['Light'], color='g', marker='*', label='Not Occupied')
plt.scatter(data[data['Occupancy'] == 1]['CO2'], 
            data[data['Occupancy'] == 1]['Light'], color='r',label='Occupied')
plt.xlabel('CO2')
plt.ylabel('Light')
plt.legend()
plt.show()

# %%
pd.plotting.scatter_matrix(df[['Temperature', 'CO2', 'Light', 'Humidity']])
plt.show()

# %%
df['Light'].value_counts()
# Out:
# 0.000000      5160
# 433.000000     230
# 444.000000     108
# 454.000000      86
# 438.000000      73
#               ...
# 491.500000       1
# 708.750000       1
# 535.666667       1
# 352.250000       1
# 545.333333       1
# Name: Light, Length: 889, dtype: int64

# %%
df['Temperature'].value_counts()
# Out:
# 19.390000    532
# 20.290000    416
# 19.500000    357
# 20.500000    328
# 19.290000    270
#             ...
# 20.381667      1
# 22.730000      1
# 22.272000      1
# 23.040000      1
# 19.175000      1
# Name: Temperature, Length: 265, dtype: int64

# %%
df['CO2'].value_counts()
# Out:
# 439.000000     132
# 437.000000     127
# 438.000000     125
# 435.000000     119
# 441.000000     117
#               ...
# 1307.000000      1
# 1111.250000      1
# 1184.666667      1
# 954.750000       1
# 629.333333       1
# Name: CO2, Length: 2282, dtype: int64

# %%
df['Humidity'].value_counts()
# Out:
# 33.000000    204
# 32.900000    177
# 18.700000    153
# 19.290000    137
# 26.700000    130
#             ...
# 19.865000      1
# 19.367500      1
# 25.497500      1
# 21.697500      1
# 32.333333      1
# Name: Humidity, Length: 1325, dtype: int64

# %%
data['Occupancy'].value_counts().plot(kind='bar', 
                                   title='Death and Survival Counts')
plt.show()

# %%
df['Light'].value_counts()
# Out:
# 0.000000      5160
# 433.000000     230
# 444.000000     108
# 454.000000      86
# 438.000000      73
#               ...
# 491.500000       1
# 708.750000       1
# 535.666667       1
# 352.250000       1
# 545.333333       1
# Name: Light, Length: 889, dtype: int64

# %% [raw]
# Il LUX(simbolo lx) è l'unità di misura per l'illuminamento, accettata dal Sistema Internazionale. Un lux è pari a un lumen su metro quadrato. Potremmo quindi definire il lux come il flusso luminoso per unità di superficie.
#
# È un'unità di misura relativa alla luce visibile, e pertanto dipendente dalle caratteristiche dell'occhio umano, attraverso la curva di sensibilità dell'occhio alla radiazione luminosa.
#
# Si ha:[1]
#
# {\displaystyle \mathrm {1\,lx=1\,{\frac {lm}{m^{2}}}=1\,{\frac {cd\cdot sr}{m^{2}}}} }{\displaystyle \mathrm {1\,lx=1\,{\frac {lm}{m^{2}}}=1\,{\frac {cd\cdot sr}{m^{2}}}} }.
# Alcuni dati di illuminamento per dare un'idea di quanto vale un lux:
#
# la luce del Sole mediamente varia tra i 32 000 lx (32 klx) e i 100 000 lx (100 klx);
# sotto i riflettori degli studi televisivi si hanno circa 1 000 lx (1 klx);
# in un campo di calcio con illuminazione notturna per riprese tv si hanno da un minimo di 500 lx ad un massimo di 1200 lx;
# in un ufficio luminoso si hanno circa 400 lx;
# in un ufficio illuminato secondo l'attuale normativa europea Uni En 12464 vi sono 500 lx;
# la luce riflessa della Luna piena è pari a circa 1 lx;[senza fonte]
# la luce di una stella luminosa è soltanto 0,00005 lx (50 µlx).

# %%
data['Occupancy'].value_counts()
# Out:
# 0    6414
# 1    1729
# Name: Occupancy, dtype: int64

# %%
data['Temperature'].plot(kind='hist', bins=20, title='Temperature')
plt.show()

# %%
data['Temperature'].describe()
# Out:
# count    8143.000000
# mean       20.619084
# std         1.016916
# min        19.000000
# 25%        19.700000
# 50%        20.390000
# 75%        21.390000
# max        23.180000
# Name: Temperature, dtype: float64

# %%
for inx,item in enumerate(data['Light']):
    data.at[inx+1,'Light'] = math.trunc(item/100)*100

# %%
plotL = pd.crosstab(data['Light'], data['Occupancy'])
plotLn = plotL.div(plotL.sum(1).astype(float), axis=0)
plotLn.plot(kind='bar', stacked=True, 
                   title='Rapporto Luce per Occupancy')
plt.xlabel('Light')
plt.ylabel('Occupancy')
# Out:
# Text(0, 0.5, 'Occupancy')

# %%
for inx,item in enumerate(data['CO2']):
    data.at[inx+1,'CO2'] = math.trunc(item/100)*100

# %%
plotC = pd.crosstab(data['CO2'], data['Occupancy'])
plotCn = plotC.div(plotC.sum(1).astype(float), axis=0)
plotCn.plot(kind='bar', stacked=True, 
                   title='Rapporto CO2 per Occupancy')
plt.xlabel('CO2')
plt.ylabel('Occupancy')
# Out:
# Text(0, 0.5, 'Occupancy')
